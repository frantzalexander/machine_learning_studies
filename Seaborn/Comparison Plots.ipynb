# %% [markdown]
# # Comparison Plots

# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ---

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("../../large-scale+wave+energy+farm/WEC_Perth_49.csv")
df.head()
# Out:
#       X1    Y1      X2     Y2      X3     Y3      X4      Y4     X5   Y5  ...  \
# 0  600.0   0.0  546.16  37.50  489.79  74.88  432.47  112.05  650.0  0.0  ...
# 1  593.0  12.0  546.16  37.50  489.79  74.88  432.47  112.05  644.0  8.0  ...
# 2  593.0  12.0  546.16  37.50  489.79  74.88  432.47  112.05  644.0  8.0  ...
# 3  593.0  12.0  546.16  37.50  489.79  74.88  432.47  112.05  644.0  8.0  ...
# 4  200.0   0.0  146.17  37.53   89.76  74.93   32.40  112.18  400.0  0.0  ...
#
#     Power42   Power43    Power44   Power45    Power46    Power47   Power48  \
# 0  88867.92  98844.30  101283.59  98934.63  101624.58  100915.03  99625.68
# 1  88896.55  98759.79  101346.07  98873.59  101629.01  100934.53  99606.13
# 2  88919.83  98746.68  101346.15  98875.57  101618.32  100941.00  99611.35
# 3  88855.14  98760.96  101338.59  98971.58  101632.28  100943.59  99589.25
# 4  88005.30  98630.24  100432.73  98803.01  101064.48  100948.38  99028.87
#
#     Power49    qW  Total_Power
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36043 entries, 0 to 36042
# Columns: 149 entries, X1 to Total_Power
# dtypes: float64(149)
# memory usage: 41.0 MB

# %%
x_columns = [f"X{x}" for x in range(1, 50)]
y_columns = [f"Y{y}" for y in range(1, 50)]
wecs_columns = x_columns + y_columns + ["qW", "Total_Power"]

# %%
df[wecs_columns].head()
# Out:
#       X1      X2      X3      X4     X5      X6      X7     X8     X9     X10  \
# 0  600.0  546.16  489.79  432.47  650.0  700.00  750.00  800.0  850.0  900.00
# 1  593.0  546.16  489.79  432.47  644.0  700.00  750.00  800.0  850.0  900.00
# 2  593.0  546.16  489.79  432.47  644.0  697.00  750.00  800.0  850.0  900.00
# 3  593.0  546.16  489.79  432.47  644.0  697.00  750.00  800.0  850.0  900.00
# 4  200.0  146.17   89.76   32.40  400.0  346.17  289.76  232.4  800.0  746.17
#
#    ...     Y42     Y43     Y44    Y45     Y46     Y47     Y48     Y49    qW  \
# 0  ...  837.50  874.88  912.05  800.0  837.50  874.88  912.05  1010.0  0.87
# 1  ...  837.50  874.88  912.05  800.0  837.50  874.88  912.05  1010.0  0.87
# 2  ...  837.50  874.88  912.05  800.0  837.50  874.88  912.05  1010.0  0.87
# 3  ...  837.50  874.88  912.05  800.0  837.50  874.88  912.05  1010.0  0.87
# 4  ...  837.53  874.93  912.18  800.0  837.53  874.93  912.18  1010.0  0.79
#
#    Total_Power
# 0   4102461.43
# ...

# %%
df_wecs = df[wecs_columns].copy()

# %%
sns.jointplot(
    data = df_wecs,
    x = "X1",
    y = "Y1",
    kind = "hex"
);

# %%
sns.displot(
    data = df_wecs,
    x = "Total_Power",
    bins = 30
);

# %%
df = pd.read_csv("../DATA/tips.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
sns.jointplot(
    data = df,
    x = "total_bill",
    y = "price_per_person",
    kind = "hex"
);

# %%
sns.jointplot(
    data = df,
    x = "total_bill",
    y = "price_per_person",
    kind = "hist"
);

# %%
sns.jointplot(
    data = df,
    x = "total_bill",
    y = "tip",
    kind = "kde",
    fill = True
);

# %%
sns.jointplot(
    data = df,
    x = "total_bill",
    y = "tip",
    hue = "sex",
    kind = "scatter",
);

# %%
sns.pairplot(df);

# %%
sns.pairplot(
    data = df,
    hue = "sex"
    );

# %%
sns.pairplot(
    data = df,
    hue = "sex",
    corner = True
    );
